# %%
import pandas as pd
df = pd.read_parquet('../data/df.parquet.gzip')
df
# Out:
#           id    source                                              title  \
# 40         0     tempo  Kapolri Instruksikan Proses Tegas Kasus Suap P...
# 42         1     tempo  Terdampak Banjir, Mentan Siap Bantu Petani di ...
# 43         2     tempo  Kementan Upayakan Perizinan Mudah, Cepat, dan ...
# 44         3     tempo  Wapres Maruf Amin Dorong Pengusaha Sawit Perku...
# 45         4     tempo  Menpan RB: Minat ASN Muda Pindah ke IKN Nusant...
# ...      ...       ...                                                ...
# 32730  32289  kumparan  5 Hewan Aneh yang Hidup di Palung Mariana, Sal...
# 32731  32290  kumparan  Biadab! Guru SD di Banyuwangi Cabuli Siswinya,...
# 32732  32291  kumparan  Aji Santoso: Jakmania Perlakukan Persebaya den...
# 32733  32292  kumparan  Sopir Audi Cium Kaki Ibu & Istri Hamil Usai Si...
# 32734  32293     tempo          Ini Besaran Biaya Haji 2023 per Embarkasi
#
#                                                  content  \
# ...
