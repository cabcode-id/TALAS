# %%
# !pip install scrapling
# Out:
# ...
#    ---------------------------------------- 0.0/34.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/34.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/34.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/34.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/34.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/34.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/34.8 MB ? eta -:--:--
#    ---------------------------------------- 0.3/34.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/34.8 MB 621.2 kB/s eta 0:00:56
#     --------------------------------------- 0.5/34.8 MB 621.2 kB/s eta 0:00:56
#     --------------------------------------- 0.8/34.8 MB 645.7 kB/s eta 0:00:53
#     --------------------------------------- 0.8/34.8 MB 645.7 kB/s eta 0:00:53
#    - -------------------------------------- 1.0/34.8 MB 709.1 kB/s eta 0:00:48
# ...

# %%
from scrapling.fetchers import StealthyFetcher, Fetcher
import nest_asyncio
nest_asyncio.apply()

# %%
url = 'https://www.instagram.com/explore/search/keyword/?q=%23pantaisanur'

# %%
page = StealthyFetcher.fetch(url, disable_resources=True, network_idle=500)
# page = Fetcher.get(url)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 page = StealthyFetcher.fetch(url, disable_resources=True, network_idle=500)
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python312\Lib\site-packages\scrapling\fetchers.py:299, in StealthyFetcher.fetch(cls, url, headless, block_images, disable_resources, block_webrtc, allow_webgl, network_idle, addons, wait, timeout, page_action, wait_selector, humanize, wait_selector_state, google_search, extra_headers, proxy, os_randomize, disable_ads, geoip, custom_config, additional_arguments)
#     274     ValueError(f"The custom parser config must be of type dictionary, got {cls.__class__}")
#     276 engine = CamoufoxEngine(
#     277     wait=wait,
#     278     proxy=proxy,
#    (...)
#     297     additional_arguments=additional_arguments or {}
#     298 )
# --> 299 return engine.fetch(url)
#
# ...

# %%
page.find_all('div', class_='_aagv')
# Out:
# []

# %%
# Example from documentation
def scrape_amazon_product(url):
    # Use StealthyFetcher to bypass protection
    page = StealthyFetcher.fetch(url)

    # Extract product details
    return {
        'title': page.css_first('#productTitle::text').clean(),
        'price': page.css_first('.a-price .a-offscreen::text'),
        'rating': page.css_first('[data-feature-name="averageCustomerReviews"] .a-popover-trigger .a-color-base::text'),
        'reviews_count': page.css('#acrCustomerReviewText::text').re_first(r'[\d,]+'),
        'features': [
            li.clean() for li in page.css('#feature-bullets li span::text')
        ],
        'availability': page.css_first('#availability').get_all_text(strip=True),
        'images': [
            img.attrib['src'] for img in page.css('#altImages img')
        ]
    }

# %%
scrape_amazon_product('https://www.amazon.com/Flowstate-3-Position-Compatible-Insulated-Stainless/dp/B0DR9PNXX3/142-3022609-5146713?pd_rd_w=B6bWE&content-id=amzn1.sym.7379aab7-0dd8-4729-b0b5-2074f1cb413d&pf_rd_p=7379aab7-0dd8-4729-b0b5-2074f1cb413d&pf_rd_r=NSZ4KTGRJ2H6J09JXVNE&pd_rd_wg=37x2c&pd_rd_r=b3c5be92-47af-46e8-97b7-e32512cc5dad&pd_rd_i=B0DR9PNXX3&psc=1')
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 scrape_amazon_product('https://www.amazon.com/dp/B08N5WRWNW')
#
# Cell In[18], line 3, in scrape_amazon_product(url)
#       1 def scrape_amazon_product(url):
#       2     # Use StealthyFetcher to bypass protection
# ----> 3     page = StealthyFetcher.fetch(url)
#       5     # Extract product details
#       6     return {
#       7         'title': page.css_first('#productTitle::text').clean(),
#       8         'price': page.css_first('.a-price .a-offscreen::text'),
#    (...)
#      17         ]
#      18     }
#
# ...
